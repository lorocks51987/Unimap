# %%
#calculadora

n1 = int(input("Digite o primeiro valor: "))

print("1 - soma")
print("2 - Subtração")
print("3 - Divisão")
print("4 - Multiplicação")

op = int(input("Escolha a operação: "))

n2 = int(input("Digite o segundo valor: "))

resultado = 0

if op == 1:
 resultado = n1 + n2
elif op == 2:
  resultado = n1 - n2
elif op == 3:
     resultado =  n1 // n2
elif op == 4:
       resultado =  n1 * n2
print("Resultado da operação é: ", resultado)

continuar = input("Deseja continuar? (s/n): ")

while continuar == "s":

    print("1 - soma")
    print("2 - Subtração")
    print("3 - Divisão")
    print("4 - Multiplicação")
    op = int(input("Escolha a operação: "))

    n3 = int(input("Digite o proximo valor: "))

    if op == 1:
        resultado2 = resultado + n3
    elif op == 2:
        resultado2 = resultado - n3
    elif op == 3:
        resultado2 = resultado // n3
    elif op == 4:
        resultado2 = resultado * n3

    print("Resultado da operação é: ", resultado2)

    continuar = input("Deseja continuar? (s/n): ")


print("Resultado da operação é: ", resultado2)
# Out:
# Digite o primeiro valor: 10
# 1 - soma
# 2 - Subtração
# 3 - Divisão
# 4 - Multiplicação
# Escolha a operação: 1
# Digite o segundo valor: 30
# Resultado da operação é:  40
# Deseja continuar? (s/n): s
# 1 - soma
# 2 - Subtração
# 3 - Divisão
# 4 - Multiplicação
# Escolha a operação: 4
# Digite o proximo valor: 5
# Resultado da operação é:  200
# Deseja continuar? (s/n): n
# Resultado da operação é:  200
