# %%
  palavra = input("Digite a palavra: ")
vogais = ("aeiouAEIOU")
contador = 0
for char in palavra:
  if char in vogais:
    contador += 1
print("O número de vogais na palavra é:", contador)
# Out:
# Digite a palavra: palavra
# O número de vogais na palavra é: 3

# %%
#teste

largura_garagem = float(input("Entre com a largura da garagem em metros: "))
profundidade_garagem = float(input("Entre com a profundidade da garagem em metros: "))

area_garagem = largura_garagem * profundidade_garagem


largura_terreno = float(input("Entre com a largurado terreno em metros: "))
profundidade_terreno = float(input("Entre com a profundidade terreno em metros: "))

area_terreno = largura_terreno * profundidade_terreno

percentual = ((area_garagem)/(area_terreno))* 100

zona = input("Entre com a zona de localizção: Sul-S, Norte-N, Leste-L e Oste-W :")

print("Imovel localizado na zona: ", zona)
print("percentual de ocupação: ", percentual)

if zona == "N" and percentual<= 25:
  print("Projeto atende norma de zoneamento do plano diretor")
elif zona == "L" or zona == "W" and percentual<= 30:
  print("Projeto atende norma de zoneamento do plano diretor")
elif zona == "S" and percentual<= 40:
  print("Projeto atende norma de zoneamento do plano diretor")
else:
  print("Revisar medidas, Projeto NÃO atende norma de zoneamento do plano diretor")

# %%
string = input("Digite a palavra a ser invertida: ")

print(string[::-1])
# Out:
# Digite a palavra a ser invertida: carro
# orrac

# %%
n = int(input("Digite o numero que deseja saber o fatorial: "))
resultado = 1

for i in range(1, n + 1):
  resultado *= i

print("O fatorial de", n, "é:", resultado )
# Out:
# Digite o numero que deseja saber o fatorial: 5
# O fatorial de 5 é: 120

# %%
n = int(input())
q = 0
for i in range(n):
  l, c = [int(i) for i in input().split()]
  if l > c:
    q += c
print(q)
# Out:
# 2
# 3 1
# 1 5
# 1

# %%
n, k = [int(i) for i in input().split()]
chamada = []
for i in range(n):
  chamada.append(input())
chamada.sort()
print(chamada[k-1])
# Out:
# 3 1
# maria
# joao
# carlos
# carlos

# %%
pedbot = 500

funcionario = int(input("Qual o salario do funcionario: "))

anual1 = funcionario * 12
anual2 = pedbot * 12

print("com uma ano de salario do funcionario que é igual a : ", anual1, " você economiza: ",anual1 - anual2, " usando ped bot")
# Out:
# Qual o salario do funcionario: 1500
# com uma ano de salario do funcionario que é igual a :  18000  você economiza:  12000  usando ped bot

# %%
#matriz

matriz = [[2,5]]
